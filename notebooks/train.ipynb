# %%
import numpy as np
import pandas as pd
from typing import Tuple
from datetime import datetime
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
base_path = "C:/Users/99818854/Projetos/GitRep/adaptive_learning"

# %%
base = pd.read_csv(f"{base_path}/data/mastery.csv")
submit = pd.read_csv(f"{base_path}/data/Submit.csv", sep=";")

# %%
def objective_function(params: np.array):
    mastery = np.dot(base.values[:, 3:-1], params)
    X, y = np.concatenate((base.values[:, 2:3], mastery), axis=1), base.values[:, -1]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

    mean_difficulty = round(np.nanmean(X_train[:, 0]))
    X_train[np.isnan(X_train)] = mean_difficulty
    X_test[np.isnan(X_test)] = mean_difficulty

    model = SGDClassifier(loss="log")
    model.fit(X_train, y_train)

    y_pred_test = model.predict(X_test)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred_test).ravel()

    accuracy = (tp + tn) / (tn + fp + fn + tp)
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1 = 2 * (precision * recall) / (precision + recall)

    return accuracy, precision, recall, f1

# %%
def random_params():
    # ganho | dificuldade 1 | dificuldade 2 | dificuldade 3 | dificuldade 4 | dificuldade 5
    return [
        np.random.randint(1, 5),
        np.random.random(),
        np.random.random(),
        np.random.random(),
        np.random.random(),
        np.random.random()
    ]

# %%
def evaluate(population: list):
    results = []
    start_date = datetime.now()
    for i in range(0, len(population)):
        print(f"Avaliando o indivíduo {i + 1}/{len(population)} da população...", end="\r")
        accuracy, precision, recall, f1 = objective_function(np.array(population[i]).reshape((len(population[i]), 1)))
        results.append(f1)

    end_date = datetime.now()
    duration = round((end_date - start_date).seconds / 60, 2)
    print(f"Melhor F1-Score encontrado: {f1} ({duration} min)")
    return results

# %%
def select(population, results):
    combination = list(zip(population, results))
    select_1 = combination[np.random.randint(0, len(combination))]
    select_2 = combination[np.random.randint(0, len(combination))]
    return select_1[0] if select_1[1] > select_2[1] else select_2[0]

# %%
def crossover(father, mother):
    element_1, element_2 = father, mother
    if np.random.randint(0, 100) < 50:
        point = np.random.randint(0, len(father))
        element_1 = father[:point] + mother[point:]
        element_2 = mother[:point] + father[point:]
    return element_1, element_2

# %%
def mutate(element):
    for i in range(0, len(element)):
        if np.random.randint(0, 100) < 2:
            element[i] = element[i] * np.random.random()

# %%
generations = 100
qntd_individuals = 10
current_population = [random_params() for i in range(0, qntd_individuals)]
print("Geração primitiva:")
current_results = evaluate(current_population)

for i in range(0, generations):
    print(f"\nGeração {i + 1}")
    new_population = []

    while len(new_population) < qntd_individuals:
        father = select(current_population, current_results)
        mother = select(current_population, current_results)
        element_1, element_2 = crossover(father, mother)
        mutate(element_1)
        mutate(element_2)
        new_population.append(element_1)
        new_population.append(element_2)

    current_population = new_population
    current_results = evaluate(current_population)
# Geração 35
# Melhor F1-Score encontrado: 0.791640569459521 (0.65 min)
# Geração 36
# Melhor F1-Score encontrado: 0.7901920872513467 (0.63 min)
# Geração 37
# Melhor F1-Score encontrado: 0.7910397536879308 (0.6 min)
# Geração 38
# Melhor F1-Score encontrado: 0.7913058819378286 (0.58 min)
# Geração 39
# Melhor F1-Score encontrado: 0.7907897760023862 (0.62 min)
# Geração 40
# Melhor F1-Score encontrado: 0.7918051220508372 (0.6 min)
# Geração 41
# Melhor F1-Score encontrado: 0.791165839958416 (0.62 min)
# Geração 42
# Melhor F1-Score encontrado: 0.7909909401599176 (0.58 min)
# Geração 43
# Melhor F1-Score encontrado: 0.7897038990073266 (0.58 min)
# Geração 44
# Melhor F1-Score encontrado: 0.789954536665759 (0.58 min)
# Geração 45
# Melhor F1-Score encontrado: 0.7906773315489105 (0.55 min)
# Geração 46
# Melhor F1-Score encontrado: 0.7899269176404403 (0.55 min)
# Geração 47
# Melhor F1-Score encontrado: 0.7899864378187642 (0.62 min)
# Geração 48
# Melhor F1-Score encontrado: 0.7906643459892224 (0.6 min)
# Geração 49
# Melhor F1-Score encontrado: 0.7892055808598318 (0.57 min)
# Geração 50
# Melhor F1-Score encontrado: 0.7909895278146644 (0.58 min)
# Geração 51
# Melhor F1-Score encontrado: 0.7905578854114068 (0.57 min)
# Geração 52
# Melhor F1-Score encontrado: 0.7912802960557461 (0.6 min)
# Geração 53
# Melhor F1-Score encontrado: 0.791482024590296 (0.58 min)
# Geração 54
# Melhor F1-Score encontrado: 0.7913504714976118 (0.6 min)
# Geração 55
# Melhor F1-Score encontrado: 0.7906842682893646 (0.58 min)
# Geração 56
# Melhor F1-Score encontrado: 0.790767230824268 (0.55 min)
# Geração 57
# Melhor F1-Score encontrado: 0.7907117367069013 (0.55 min)
# Geração 58
# Melhor F1-Score encontrado: 0.7895924897013022 (0.53 min)
# Geração 59
# Melhor F1-Score encontrado: 0.7905144085891241 (0.55 min)
# Geração 60
# Melhor F1-Score encontrado: 0.7916928886091881 (0.55 min)
# Geração 61
# Melhor F1-Score encontrado: 0.7899897950092736 (0.57 min)
# Geração 62
# Melhor F1-Score encontrado: 0.7912871622234177 (0.57 min)
# Geração 63
# Melhor F1-Score encontrado: 0.7885517882251254 (0.57 min)
# Geração 64
# Melhor F1-Score encontrado: 0.7908632070671194 (0.58 min)
# Geração 65
# Melhor F1-Score encontrado: 0.7911062753750214 (0.57 min)
# Geração 66
# Melhor F1-Score encontrado: 0.7900112956414196 (0.55 min)
# Geração 67
# Melhor F1-Score encontrado: 0.7908443778014252 (0.57 min)
# Geração 68
# Melhor F1-Score encontrado: 0.7905613520181902 (0.57 min)
# Geração 69
# Melhor F1-Score encontrado: 0.790619437988676 (0.58 min)
# Geração 70
# Melhor F1-Score encontrado: 0.790993525349476 (0.6 min)
# Geração 71
# Melhor F1-Score encontrado: 0.7911536625021911 (0.55 min)
# Geração 72
# Melhor F1-Score encontrado: 0.7917105937532409 (0.57 min)
# Geração 73
# Melhor F1-Score encontrado: 0.7909973612329964 (0.57 min)
# Geração 74
# Melhor F1-Score encontrado: 0.7910685644741402 (0.58 min)
# Geração 75
# Melhor F1-Score encontrado: 0.7906387507584018 (0.55 min)
# Geração 76
# Melhor F1-Score encontrado: 0.7890664695126218 (0.55 min)
# Geração 77
# Melhor F1-Score encontrado: 0.7912258610442333 (0.55 min)
# Geração 78
# Melhor F1-Score encontrado: 0.7907336716636904 (0.58 min)
# Geração 79
# Melhor F1-Score encontrado: 0.7905349350370504 (0.55 min)
# Geração 80
# Melhor F1-Score encontrado: 0.7910238881371404 (0.57 min)
# Geração 81
# Melhor F1-Score encontrado: 0.7915103602809738 (0.55 min)
# Geração 82
# Melhor F1-Score encontrado: 0.7910623237595543 (0.55 min)
# Geração 83
# Melhor F1-Score encontrado: 0.7911183464916743 (0.53 min)
# Geração 84
# Melhor F1-Score encontrado: 0.7912133296935423 (0.55 min)
# Geração 85
# Melhor F1-Score encontrado: 0.7906346749226005 (0.57 min)
# Geração 86
# Melhor F1-Score encontrado: 0.7911792348768968 (0.55 min)
# Geração 87
# Melhor F1-Score encontrado: 0.7910477082798121 (0.6 min)
# Geração 88
# Melhor F1-Score encontrado: 0.7909685349561222 (0.57 min)
# Geração 89
# Melhor F1-Score encontrado: 0.7910221303399042 (0.57 min)
# Geração 90
# Melhor F1-Score encontrado: 0.7910416183922868 (0.55 min)
# Geração 91
# Melhor F1-Score encontrado: 0.790660269259491 (0.57 min)
# Geração 92
# Melhor F1-Score encontrado: 0.7913034281656518 (0.55 min)
# Geração 93
# Melhor F1-Score encontrado: 0.790440854069713 (0.55 min)
# Geração 94
# Melhor F1-Score encontrado: 0.7915663414973098 (0.55 min)
# Geração 95
# Melhor F1-Score encontrado: 0.7912547279567672 (0.57 min)
# Geração 96
# Melhor F1-Score encontrado: 0.7906761128299187 (0.55 min)
# Geração 97
# Melhor F1-Score encontrado: 0.7907047531504401 (0.55 min)
# Geração 98
# Melhor F1-Score encontrado: 0.7911161623336649 (0.55 min)
# Geração 99
# Melhor F1-Score encontrado: 0.790416119371088 (0.55 min)
# Geração 100
# Melhor F1-Score encontrado: 0.7905261916592671 (0.55 min)

# %%
best_f1, best_population = 0, []
for population, f1 in zip(current_population, current_results):
    if f1 > best_f1:
        best_f1 = f1
        best_population = population

print(f"Melhores parâmetros:")
print(best_population)
# Out:
# Melhores parâmetros:
# [0.0004323906784531435, 0.00010716995653383348, 0.09686397157158075, 0.038338290750789344, 0.1925561952638974, 7.024947822136203e-06]
